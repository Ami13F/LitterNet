# %% [markdown]
# # Article Steps
# 1. Dataset details
#     * super category and category statistics
#     * num of datas charts(per supercategory, image dimm, object size(small, med, large)
#     (prepare_data.ipynb)
#
# 2.  Taco dataset preparation
#     * split dataset(test, train, validation)
#     * ground truth extraction (labels for images)
#     * resize
#     * data **augumentation**
#     (prepare_data.ipynb)
#
# 3. Train yolo with Taco
#     * write metric results (mAP, perf, acc, recall, iou)
#
# 4. Model intro
#     *
#
# ### Obs
#  - due to the fact that taco is still a relatively new dataset, we've combined more images

# %% [markdown]
# # Our steps(TODOS)
# 1. [x] compile darknet
# 2. [x] get taco dataset
# 3. [x] train basic taco (darknet53.conv.74 pre-trained)
# 4. [ ] augument taco dataset (add new img, crop, flip)
# 5. [ ] train taco augumented yolov3
# 6. [ ] iterate 4, 5 until very good results are obtained
# 7. [ ] train cspnet on taco augumented
# 8. [ ] get best from 3,5 and 6
